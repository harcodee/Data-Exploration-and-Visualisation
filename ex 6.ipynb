# %%
import pandas as pd
import numpy as np
import folium

# Generate random data
np.random.seed(42)
num_points = 100
latitude = np.random.uniform(37.5, 38.5, num_points)
longitude = np.random.uniform(-123, -121, num_points)
value = np.random.randint(1, 100, num_points)

# Create a DataFrame
df = pd.DataFrame({'Latitude': latitude, 'Longitude': longitude, 'Value': value})

# Save the DataFrame to a CSV file
df.to_csv('map_data.csv', index=False)

# Load the generated CSV file
df = pd.read_csv('map_data.csv')

# Create a base map
base_map = folium.Map(location=[df['Latitude'].mean(), df['Longitude'].mean()],
                      zoom_start=10)

# Add data points to the map
for index, row in df.iterrows():
    popup_text = f"Value: {row['Value']}"
    folium.Marker([row['Latitude'], row['Longitude']], 
                  popup=popup_text).add_to(base_map)

# Show basic statistics
print("Basic Statistics:")
print(df.describe())

# Display the map inline in Jupyter
base_map
# Out:
# Basic Statistics:
#          Latitude   Longitude       Value
# count  100.000000  100.000000  100.000000
# mean    37.970181 -122.004337   50.670000
# std      0.297489    0.586223   28.640247
# min     37.505522 -122.986096    2.000000
# 25%     37.693201 -122.515991   27.000000
# 50%     37.964142 -121.988750   47.500000
# 75%     38.230203 -121.467633   72.750000
# max     38.486887 -121.028699   99.000000
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a548e3ef35f933ac3c360b3d109efd5c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a548e3ef35f933ac3c360b3d109efd5c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a548e3ef35f933ac3c360b3d109efd5c = L.map(
#                 &quot;map_a548e3ef35f933ac3c360b3d109efd5c&quot;,
#                 {
#                     center: [37.970180743378215, -122.00433655368994],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4523affc626f923f9be69670e52e206f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4523affc626f923f9be69670e52e206f.addTo(map_a548e3ef35f933ac3c360b3d109efd5c);
#
#
#             var marker_b7d6b960b886383108fbc9e16eda1cd2 = L.marker(
#                 [37.87454011884736, -122.93714162862652],
#                 {
# }
#             ).addTo(map_a548e3ef35f933ac3c360b3d109efd5c);
#
#
#         var popup_182fc6e62a152360013805ee20b9f8b8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_12a54400298148265892c5c02891a724 = $(`&lt;div id=&quot;html_12a54400298148265892c5c02891a724&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Value: 24.0&lt;/div&gt;`)[0];
#                 popup_182fc6e62a152360013805ee20b9f8b8.setContent(html_12a54400298148265892c5c02891a724);
#
#
#
#         marker_b7d6b960b886383108fbc9e16eda1cd2.bindPopup(popup_182fc6e62a152360013805ee20b9f8b8)
#         ;
#
#
#
#
#             var marker_499f4a9f6babff0104f7f05b6415942a = L.marker(
#                 [38.45071430640992, -121.72717917747244],
#                 {
# }
#             ).addTo(map_a548e3ef35f933ac3c360b3d109efd5c);
#
#
#         var popup_72d538bc0d256db2c7a6fd6869274207 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e5c63836e3017dc8e30b3c438168b76c = $(`&lt;div id=&quot;html_e5c63836e3017dc8e30b3c438168b76c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Value: 75.0&lt;/div&gt;`)[0];
#                 popup_72d538bc0d256db2c7a6fd6869274207.setContent(html_e5c63836e3017dc8e30b3c438168b76c);
#
#
#
#         marker_499f4a9f6babff0104f7f05b6415942a.bindPopup(popup_72d538bc0d256db2c7a6fd6869274207)
#         ;
#
#
#
#
#             var marker_6c38a3dc11b0dbc203a5123ce4a9d62c = L.marker(
#                 [38.2319939418114, -122.37128803784736],
#                 {
# }
#             ).addTo(map_a548e3ef35f933ac3c360b3d109efd5c);
#
#
#         var popup_1c8dddf0c6b3bd7dcad8033164cc2694 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a3da9f18a6a71acd298c5b811f8fcd15 = $(`&lt;div id=&quot;html_a3da9f18a6a71acd298c5b811f8fcd15&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Value: 72.0&lt;/div&gt;`)[0];
#                 popup_1c8dddf0c6b3bd7dcad8033164cc2694.setContent(html_a3da9f18a6a71acd298c5b811f8fcd15);
#
#
#
#         marker_6c38a3dc11b0dbc203a5123ce4a9d62c.bindPopup(popup_1c8dddf0c6b3bd7dcad8033164cc2694)
#         ;
#
#
#
#
#             var marker_9b7ec682aacc0b10112db8f79f9b334b = L.marker(
#                 [38.09865848419704, -121.9828586176706],
#                 {
# }
#             ).addTo(map_a548e3ef35f933ac3c360b3d109efd5c);
#
#
#         var popup_8f0acd577b18ae46c7b34c8c9a1013b0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_854977c47b55d8c1a9a3315358ea43f9 = $(`&lt;div id=&quot;html_854977c47b55d8c1a9a3315358ea43f9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Value: 36.0&lt;/div&gt;`)[0];
#                 popup_8f0acd577b18ae46c7b34c8c9a1013b0.setContent(html_854977c47b55d8c1a9a3315358ea43f9);
#
#
#
#         marker_9b7ec682aacc0b10112db8f79f9b334b.bindPopup(popup_8f0acd577b18ae46c7b34c8c9a1013b0)
#         ;
#
#
#
#
#             var marker_3e0b41206b97e7c01d8a867ab60c96a9 = L.marker(
#                 [37.65601864044244, -121.1848670521478],
#                 {
# }
#             ).addTo(map_a548e3ef35f933ac3c360b3d109efd5c);
#
#
#         var popup_2febbca3086d66ce79fc1b44c51a68b9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_87ab11f7d7b93a3eac74f3614f38785b = $(`&lt;div id=&quot;html_87ab11f7d7b93a3eac74f3614f38785b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Value: 38.0&lt;/div&gt;`)[0];
#                 popup_2febbca3086d66ce79fc1b44c51

# %%
# requirements
# !pip install folium
